# %% [markdown]
# <a href="https://colab.research.google.com/github/anjucvijayan/Basics/blob/main/RNN_NEXTWORD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
